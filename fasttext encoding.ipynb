# %% [markdown]
# <h3>Download and explore pre-trained models</h3>

# %%
# !pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from fasttext) (67.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp39-cp39-linux_x86_64.whl size=4395791 sha256=bc128c7cb3cea120128215c55fe4046f53966af82be1197977a49d8cee6d5d6a
#   Stored in directory: /root/.cache/pip/wheels/64/57/bc/1741406019061d5664914b070bd3e71f6244648732bc96109e
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import fasttext
import fasttext.util

# %%
fasttext.util.download_model('en', if_exists='ignore')  # English
ft = fasttext.load_model('cc.en.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/NLP/revpre.csv",nrows=5000)
df.head()
# Out:
#    Unnamed: 0                                             Review  Rating  \
# 0           0     'absolutely wonderful silky sexy comfortable '       4
# 1           1  'love dress sooo pretty happened find store im...       5
# 2           2  ' high hopes dress really wanted work initiall...       3
# 3           3  ' love love love jumpsuit fun flirty fabulous ...       5
# 4           4  'this shirt flattering due adjustable front ti...       5
#
#    Positive Feedback Count
# 0                        0
# 1                        4
# 2                        0
# 3                        0
# 4                        6

# %%
ft.get_nearest_neighbors('good')
# Out:
# [(0.7833111882209778, 'bad'),
#  (0.6906806230545044, 'semi-good'),
#  (0.6772378087043762, 'geat'),
#  (0.6678460240364075, 'goood'),
#  (0.6671645045280457, 'good-'),
#  (0.6620287299156189, 'excellent'),
#  (0.6374278664588928, 'agood'),
#  (0.635202169418335, 'ggod'),
#  (0.6334646940231323, 'great'),
#  (0.6278809309005737, 'good-ish')]

# %%
vect =ft.get_sentence_vector("some string")
vect
# Out:
# array([-5.10768108e-02, -3.51970978e-02,  1.52374320e-02, -3.38926613e-02,
#         1.41485408e-03,  3.67529206e-02,  4.52132784e-02,  1.06462389e-02,
#         4.50741202e-02, -2.03452725e-03, -9.46560688e-03, -6.34375494e-03,
#        -2.61745788e-03,  7.37033933e-02, -2.90964190e-02, -1.09510548e-01,
#        -1.20413210e-02,  2.02795994e-02,  1.67240053e-02, -1.01138480e-01,
#        -9.23667103e-04,  3.97215895e-02,  2.99315359e-02, -8.11491534e-02,
#        -2.03097641e-01, -9.63106379e-02, -1.28462911e-02,  5.38475998e-02,
#        -6.14640042e-02,  8.16890225e-02,  1.12294909e-02,  1.95285305e-03,
#         3.22366506e-02,  1.62065309e-02, -2.40263529e-02, -3.43521796e-02,
#         2.05696691e-02, -8.30687732e-02,  1.17022078e-02,  3.66486865e-03,
#        -9.50939301e-03,  7.09190443e-02,  5.63842207e-02, -2.65707131e-02,
#        -6.16107360e-02,  9.48151648e-02,  4.71629761e-03,  1.48620615e-02,
#        -4.95241322e-02,  4.35641035e-02, -7.90959224e-04,  3.66466567e-02,
#        -5.04793003e-02, -4.80401050e-03,  1.60369202e-02, -7.77318031e-02,
#        -1.37325907e-02,  5.23573533e-02,  3.80349569e-02, -3.40431072e-02,
#        -5.32113314e-02, -1.13794859e-02, -3.75721604e-02,  7.26602506e-03,
#         2.44762134e-02, -3.17907184e-02, -2.28292160e-02, -2.49839500e-02,
#        -3.19528952e-02, -1.74687002e-02, -5.79991266e-02, -3.58967297e-02,
#         1.08125741e-02,  1.86638921e-01,  3.10503952e-02,  1.74195487e-02,
#         2.94989087e-02,  2.89797708e-02, -6.23327270e-02, -7.11005479e-02,
#         2.36630123e-02,  3.21991444e-02, -2.03296226e-02, -2.86055868e-03,
#         9.20586139e-02, -4.78778221e-02,  3.12605612e-02, -5.99786639e-04,
#         5.76835498e-02, -4.46361005e-02,  4.64540049e-02,  1.87427793e-02,
#        -7.43323145e-03,  3.21393609e-02,  4.62977663e-02, -8.54148995e-03,
#        -6.20982833e-02,  4.99988571e-02, -9.10045952e-03, -1.23085827e-02,
#        -7.83838779e-02,  4.69271000e-03,  1.99308619e-04,  5.20599075e-03,
#        -6.24052994e-03, -3.34046632e-02, -1.79064944e-02,  3.55945453e-02,
#        -1.56183746e-02, -1.65180843e-02,  2.07667481e-02,  2.72718929e-02,
#         2.94560306e-02,  4.88365218e-02, -6.56631142e-02,  2.90689711e-02,
#         1.68300658e-01,  5.54546863e-02,  8.72508585e-02, -2.09042896e-02,
#         2.53499597e-02,  1.19696716e-02,  1.37426835e-02,  3.51908952e-02,
#         4.85774092e-02, -2.20881552e-02, -3.96748744e-02,  3.16055724e-04,
#        -2.99356002e-02, -7.35060498e-02,  1.68888997e-02,  3.98250930e-02,
#        -2.31784470e-02,  3.84959299e-03,  4.56934385e-02, -1.63382944e-02,
#         1.74069777e-04, -2.61758920e-03,  5.16471937e-02,  2.38089059e-02,
#        -2.90212557e-02, -6.87287301e-02, -5.91748655e-02, -1.15200773e-01,
#         2.80831289e-02, -1.08268242e-02, -2.78203078e-02,  1.70711577e-02,
#        -7.45820254e-03, -2.01547295e-02, -2.38790158e-02, -3.73910964e-02,
#         1.94762126e-02, -8.90365988e-03, -8.82145017e-03,  2.45693307e-02,
#         1.01586636e-02,  1.78138874e-02, -9.09581706e-02, -4.21517435e-03,
#        -1.42385708e-02,  5.52878529e-03, -1.03820868e-01, -3.17881629e-02,
#        -3.28619033e-02,  2.09768824e-02,  1.02652274e-02, -2.32672840e-02,
#        -2.18821317e-03,  1.42841458e-01, -2.90619582e-02,  6.63644588e-03],
#       dtype=float32)

# %%
df['Review']=df['Review'].astype(str)
for item in df['Review']:
    item = item.replace("\n"," ")

# %%
df['vector']=df['Review'].apply(ft.get_sentence_vector)

# %%
model_en.get_analogies("berlin","germany","france")

# %%
model_en.get_analogies("berlin","germany","india")

# %%
model_en.get_analogies("driving","car","phone")

# %%
model_en.get_analogies("driving","car","book")

# %%
model_en.get_nearest_neighbors("chutney")
# Out:
# [(0.8078702092170715, 'chutneys'),
#  (0.7138292789459229, 'thokku'),
#  (0.701572060585022, 'Chutney'),
#  (0.6875490546226501, 'achaar'),
#  (0.684525728225708, 'piccalilli'),
#  (0.6737173199653625, 'raita'),
#  (0.6715506911277771, 'chatni'),
#  (0.6610829830169678, 'chutney.'),
#  (0.6505922675132751, 'gojju'),
#  (0.6398508548736572, 'kasundi')]

# %%
model_en.get_nearest_neighbors("halwa")
# Out:
# [(0.8563978672027588, 'kheer'),
#  (0.8392286896705627, 'burfi'),
#  (0.8193163871765137, 'Halwa'),
#  (0.7894062995910645, 'kesari'),
#  (0.778471827507019, 'payasam'),
#  (0.7706475853919983, 'burfis'),
#  (0.7590622901916504, 'laddoo'),
#  (0.7504664659500122, 'ladoo'),
#  (0.7471016645431519, 'rabdi'),
#  (0.7396334409713745, 'laddu')]

# %%
model_en.get_nearest_neighbors("saragva", k=3)
# Out:
# [(0.5384978652000427,
#   'ReportsTabloidCrimeYakuzaTokyoGinzaIkebukuroKabukichoRoppongiShibuyaShimbashiShinjukuUenoJapanChibaFukuokaKobeKyotoNagoyaOkinawaOsakaSaitamaYokohamaSportsBaseballHorse'),
#  (0.5373231768608093,
#   'NoidaVaranasiBareillyMathuraAligarhMoradabadSaharanpurBijnorJaunpurGorakhpurMuzaffarnagarSultanpurDehradunHaridwarNainitalRoorkeeGarhwalBardhamanMurshidabadHooghlyMedinipurNorth'),
#  (0.5331498980522156,
#   '...')]

# %%
#Download fastext file cc.hi.300.bin from online and provide the path
model_hi = fasttext.load_model('..........\\cc.hi.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
model_hi.get_nearest_neighbors("अच्छा")
# Out:
# [(0.6697985529899597, 'बुरा'),
#  (0.6132625341415405, 'अच्छे'),
#  (0.608695387840271, 'अच्चा'),
#  (0.6058669090270996, 'अच्छाखासा'),
#  (0.5848375558853149, 'कीअच्छा'),
#  (0.5826330184936523, 'औरअच्छा'),
#  (0.5811230540275574, 'हो.अच्छा'),
#  (0.5805407762527466, 'हीअच्छा'),
#  (0.5795978307723999, 'लगता'),
#  (0.5777745246887207, '58अच्छा')]

# %%
model_hi.get_nearest_neighbors("गाय")
# Out:
# [(0.6485272645950317, 'गायों'),
#  (0.6403631567955017, 'गोमाता'),
#  (0.6264104247093201, 'बछड़े'),
#  (0.6045769453048706, 'बछडे'),
#  (0.6030024886131287, 'दुधारु'),
#  (0.5880257487297058, 'भेंस'),
#  (0.5822192430496216, 'भैंस'),
#  (0.5819100737571716, 'दुधारू'),
#  (0.5773836970329285, 'गौमाता'),
#  (0.5771614909172058, 'गायें')]
